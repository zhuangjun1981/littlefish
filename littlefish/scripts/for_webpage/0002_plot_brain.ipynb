# %%
import littlefish.core.fish as fi
import littlefish.core.plotting as pl
import littlefish.core.evolution as evo
import random
import numpy as np

random.seed(0)
np.random.seed(0)

# %%
fish = fi.generate_standard_fish()
brain_mutation = evo.get_default_brain_mutation()
fish = evo.mutate_fish(
    fish, 
    brain_mutation=brain_mutation, 
    neuron_mutation_rate=1.,
    connection_mutation_rate=1., 
    verbose=True
)
# Out:
# mutating input brain ...
#
# mutating neurons:
# total number of neurons: 20. neuron mutation rate: 1.0. number of neurons to be mutated: 20.
# Evolution: mutating hidden neuron. Index: 12.
# Evolution: mutating hidden neuron. Index: 13.
# Evolution: mutating eye. Index: 1.
# Evolution: mutating hidden neuron. Index: 8.
# Evolution: mutating hidden neuron. Index: 15.
# Evolution: mutating eye. Index: 6.
# Evolution: mutating muscle. Index: 19.
# Evolution: mutating eye. Index: 4.
# Evolution: mutating eye. Index: 7.
# Evolution: mutating eye. Index: 5.
# Evolution: mutating hidden neuron. Index: 9.
# Evolution: mutating eye. Index: 3.
# Evolution: mutating eye. Index: 2.
# Evolution: mutating hidden neuron. Index: 11.
# Evolution: mutating muscle. Index: 17.
# Evolution: mutating eye. Index: 0.
# Evolution: mutating hidden neuron. Index: 14.
# Evolution: mutating muscle. Index: 16.
# Evolution: mutating muscle. Index: 18.
# Evolution: mutating hidden neuron. Index: 10.
#
# ...

# %%
brain = fish.get_brain()
pl.plot_brain(
    brain,
    neuron_label_kws = {
        'fontsize': 15, 'va': 'center', 'ha': 'center', 
        'color': '#000000', 'family': 'monospace', 'weight': 'semibold'
    },
    neuron_kws = {'mew': 3, 'ms': 80.},
)
# Out:
# <Axes: >
